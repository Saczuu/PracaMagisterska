# %%
import tensorflow as tf
from Model.Model import SegmentationModel
import Scripts.DataPrepering as dp
import tensorflow_datasets as tfds
from IPython.display import clear_output
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
from matplotlib.image import imread 
import numpy as np

# %%
# image = tf.io.read_file("Data/labels/staffordshire_bull_terrier_100.png")
# image = tf.image.decode_jpeg(image, channels=)
# dp.display([image])

# %%
print("Import complete")
print("Generating Model")

model = SegmentationModel.generateModel()
# Out:
# Import complete
# Generating Model

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 64, 64, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 192)  0           up_sampling2d[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   110656      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 64) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 96) 0           up_sampling2d_1[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 32) 27680       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128, 128, 32) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 32) 9248        dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 3)  99          conv2d_9[0][0]
# ==================================================================================================
# Total params: 471,619
# Trainable params: 471,619
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print("Compiling model")
print("==============")

model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# Out:
# Compiling model
# ==============

# %%
print("Loading and preparing data")
print("==============")
# Out:
# Loading and preparing data
# ==============

# %%
dp.resizeImagesInFolder("Data/images", 128, 128)
dp.resizeImagesInFolder("Data/labels", 128, 128)

# %%
X = dp.loadImages("Data/images")
Y = dp.loadMasks("Data/labels")
del X[29]
del Y[29]

X = np.asarray(X).astype('float32')
Y = np.asarray(Y).astype('float32')

# %%
Y = Y>0
Y = Y.astype(int)

# %%
X, Y = dp.normalize(X, Y)

# %%
dp.display([X[12], Y[12]])

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
# print("Train set:\n X:"+str(X_train.shape)+" y:"+str(y_train.shape)+"\n Test set:\n X:"+str(X_test.shape)+" y:"+str(y_test.shape))

# %%
TRAIN_LENGTH = X.shape[0]
EPOCHS = 25
BATCH_SIZE = 16
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
model_history = model.fit(X, Y, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          batch_size=BATCH_SIZE)
                        
model.save("model")
# Out:
# Epoch 1/25
# 3/3 [==============================] - 4s 1s/step - loss: 1.0645 - accuracy: 0.4491
# Epoch 2/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.8871 - accuracy: 0.5249
# Epoch 3/25
# 3/3 [==============================] - 2s 806ms/step - loss: 0.7464 - accuracy: 0.5441
# Epoch 4/25
# 3/3 [==============================] - 3s 857ms/step - loss: 0.7944 - accuracy: 0.5066
# Epoch 5/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.7508 - accuracy: 0.5127
# Epoch 6/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.7153 - accuracy: 0.5618
# Epoch 7/25
# 3/3 [==============================] - 3s 855ms/step - loss: 0.6861 - accuracy: 0.6003
# Epoch 8/25
# 3/3 [==============================] - 2s 810ms/step - loss: 0.6787 - accuracy: 0.5823
# Epoch 9/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.6580 - accuracy: 0.6246
# Epoch 10/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.6342 - accuracy: 0.6464
# Epoch 11/25
# 3/3 [==============================] - 2s 803ms/step - loss: 0.5944 - accuracy: 0.6879
# Epoch 12/25
# 3/3 [==============================] - 2s 806ms/step - loss: 0.6706 - accuracy: 0.6154
# Epoch 13/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.6963 - accuracy: 0.6392
# Epoch 14/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.6916 - accuracy: 0.6041
# Epoch 15/25
# 3/3 [==============================] - 2s 803ms/step - loss: 0.6918 - accuracy: 0.5830
# Epoch 16/25
# 3/3 [==============================] - 2s 806ms/step - loss: 0.6600 - accuracy: 0.6093
# Epoch 17/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.6336 - accuracy: 0.6367
# Epoch 18/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.6448 - accuracy: 0.6320
# Epoch 19/25
# 3/3 [==============================] - 3s 892ms/step - loss: 0.5863 - accuracy: 0.6957
# Epoch 20/25
# 3/3 [==============================] - 2s 831ms/step - loss: 0.5852 - accuracy: 0.6881
# Epoch 21/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.5746 - accuracy: 0.7046
# Epoch 22/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.5732 - accuracy: 0.7138
# Epoch 23/25
# 3/3 [==============================] - 2s 819ms/step - loss: 0.5629 - accuracy: 0.7194
# Epoch 24/25
# 3/3 [==============================] - 2s 796ms/step - loss: 0.6064 - accuracy: 0.6788
# Epoch 25/25
# 3/3 [==============================] - 4s 1s/step - loss: 0.5459 - accuracy: 0.7251
# WARNING:tensorflow:From C:\Users\sacze\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\sacze\anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model\assets

# %%
##Predictions
model = tf.keras.models.load_model('model')

# %%
INDEX = 49
test = X[INDEX]
test = np.reshape(test, (1,128,128,3))
predict = model.predict(test)

# %%
dp.display([X[INDEX], Y[INDEX],dp.create_mask(predict)])
